# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavipokhriyal083-sudo/Flight-Booking_Project/blob/main/Flight_Booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Flight_Booking - Flight_Booking.csv")

# %%
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
# brief summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
df.isnull()
# Out:
#         airline  flight  source_city  departure_time  stops  arrival_time  \
# 0         False   False        False           False  False         False
# 1         False   False        False           False  False         False
# 2         False   False        False           False  False         False
# 3         False   False        False           False  False         False
# 4         False   False        False           False  False         False
# ...         ...     ...          ...             ...    ...           ...
# 300148    False   False        False           False  False         False
# 300149    False   False        False           False  False         False
# 300150    False   False        False           False  False         False
# 300151    False   False        False           False  False         False
# 300152    False   False        False           False  False         False
#
#         destination_city  class  duration  days_left  price
# ...

# %%
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 300148    False
# 300149    False
# 300150    False
# 300151    False
# 300152    False
# Length: 300153, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
# airline  , price
plt.figure(figsize=(15, 5))
sns.lineplot(data=df,x='airline',y='price')
plt.title('airline vs price')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.barplot(data = df , x ='airline', y='price')
plt.title('airline vs price')
plt.show()

# %%
plt.figure(figsize =(15, 5))
sns.barplot(x ='class', y ='price', hue ='airline', data = df)
plt.show()

# %%
# check economy and business class range
print(f"Economy class range ${df[df['class']=='Economy']['price'].min(): .2f} - ${df[df['class']=='Economy']['price'].max(): .2f}")
# Out:
# Economy class range $ 1105.00 - $ 42349.00

# %%
# check Business and business class range
print(f"Business class range ${df[df['class']=='Business']['price'].min(): .2f} - ${df[df['class']=='Business']['price'].max(): .2f}")
# Out:
# Business class range $ 12000.00 - $ 123071.00

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
sns.lineplot(x='days_left', y='price', hue='source_city', data= df, ax= ax[0])
sns.lineplot(x='days_left', y='price', hue='destination_city', data= df, ax= ax[1])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le= LabelEncoder()

for col in df.columns:
  if df[col].dtype=='object':
   df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#         airline  flight  source_city  departure_time  stops  arrival_time  \
# 0             4     786            2               2      2             5
# 1             4     765            2               1      2             4
# 2             0     591            2               1      2             1
# 3             5     937            2               4      2             0
# 4             5     927            2               4      2             4
# ...         ...     ...          ...             ...    ...           ...
# 300148        5     855            1               4      0             2
# 300149        5     859            1               0      0             5
# 300150        5     864            1               1      0             5
# 300151        5     861            1               1      0             2
# 300152        5     855            1               4      0             2
#
#         destination_city  class  duration  days_left  price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299622 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           299622 non-null  int64
#  1   flight            299622 non-null  int64
#  2   source_city       299622 non-null  int64
#  3   departure_time    299622 non-null  int64
#  4   stops             299622 non-null  int64
#  5   arrival_time      299622 non-null  int64
#  6   destination_city  299622 non-null  int64
#  7   class             299622 non-null  int64
#  8   duration          299622 non-null  float64
#  9   days_left         299622 non-null  int64
#  10  price             299622 non-null  int64
# dtypes: float64(1), int64(10)
# memory usage: 27.4 MB

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
col_list=[]
for col in df.columns:
  if (df[col].dtype!='object') & (col!='price'):
    col_list.append(col)

# %%
col_list
# Out:
# ['airline',
#  'flight',
#  'source_city',
#  'departure_time',
#  'stops',
#  'arrival_time',
#  'destination_city',
#  'class',
#  'duration',
#  'days_left']

# %%
x= df[col_list]
vif_data = pd.DataFrame()
vif_data['Feature']= x.columns
vif_data['VIF']=[variance_inflation_factor(x.values, i)  for i in range(len(x.columns))]

# %%
vif_data

# vif > 5
# Out:
#             Feature       VIF
# 0           airline  8.754316
# 1            flight  7.650996
# 2       source_city  2.929767
# 3    departure_time  2.782343
# 4             stops  1.422277
# 5      arrival_time  3.688342
# 6  destination_city  2.889501
# 7             class  2.899564
# 8          duration  4.289163
# 9         days_left  3.977038

# %%
df = df.drop('airline',axis=1)

# %%
col_list=[]
for col in df.columns:
  if (df[col].dtype!='object') & (col!='price'):
    col_list.append(col)

    x= df[col_list]
vif_data = pd.DataFrame()
vif_data['Feature']= x.columns
vif_data['VIF']=[variance_inflation_factor(x.values, i)  for i in range(len(x.columns))]

# %%
vif_data
# Out:
#             Feature       VIF
# 0            flight  2.962234
# 1       source_city  2.915266
# 2    departure_time  2.764861
# 3             stops  1.419934
# 4      arrival_time  3.658769
# 5  destination_city  2.852472
# 6             class  2.873150
# 7          duration  4.274805
# 8         days_left  3.945591

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#         flight  source_city  departure_time  stops  arrival_time  \
# 0          786            2               2      2             5
# 1          765            2               1      2             4
# 2          591            2               1      2             1
# 3          937            2               4      2             0
# 4          927            2               4      2             4
# ...        ...          ...             ...    ...           ...
# 300148     855            1               4      0             2
# 300149     859            1               0      0             5
# 300150     864            1               1      0             5
# 300151     861            1               1      0             2
# 300152     855            1               4      0             2
#
#         destination_city  class  duration  days_left
# 0                      5      1      2.17          1
# 1                      5      1      2.33          1
# ...

# %%
y
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 299622, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state=42)

# %%
x_train
# Out:
#         flight  source_city  departure_time  stops  arrival_time  \
# 120522       0            4               4      0             2
# 181671       0            1               2      0             5
# 228233     164            5               1      0             2
# 22417      101            2               2      0             4
# 125657      76            4               2      0             3
# ...        ...          ...             ...    ...           ...
# 120216     275            4               4      0             2
# 259709     892            0               0      1             2
# 132310     778            4               5      0             4
# 147248     832            4               4      1             5
# 122303     211            4               0      0             4
#
#         destination_city  class  duration  days_left
# 120522                 2      1      7.08          8
# 181671                 2      1      6.67         12
# ...

# %%
x_test
# Out:
#         flight  source_city  departure_time  stops  arrival_time  \
# 95478        0            0               1      2             1
# 286074     143            3               4      0             5
# 61770      938            5               2      0             2
# 32045        0            2               4      2             4
# 139635     822            4               5      0             2
# ...        ...          ...             ...    ...           ...
# 187791       0            1               4      0             2
# 294399     100            1               1      0             3
# 37404        0            2               0      0             5
# 72996      890            5               2      0             4
# 183505     753            1               1      0             0
#
#         destination_city  class  duration  days_left
# 95478                  5      1      1.67         11
# 286074                 1      0     12.25         18
# ...

# %%
x_train.shape

x_test.shape
# Out:
# (59925, 9)

# %%
y_train
# Out:
# 120522    11370
# 181671     7877
# 228233    41101
# 22417      5805
# 125657     2994
#           ...
# 120216     9534
# 259709    63362
# 132310     5934
# 147248     7455
# 122303     5810
# Name: price, Length: 239697, dtype: int64

# %%
y_test
# Out:
# 95478      5178
# 286074    51595
# 61770      9879
# 32045      2098
# 139635     8111
#           ...
# 187791    11972
# 294399    60260
# 37404      6376
# 72996      3334
# 183505     4048
# Name: price, Length: 59925, dtype: int64

# %%
df
# Out:
#         flight  source_city  departure_time  stops  arrival_time  \
# 0          786            2               2      2             5
# 1          765            2               1      2             4
# 2          591            2               1      2             1
# 3          937            2               4      2             0
# 4          927            2               4      2             4
# ...        ...          ...             ...    ...           ...
# 300148     855            1               4      0             2
# 300149     859            1               0      0             5
# 300150     864            1               1      0             5
# 300151     861            1               1      0             2
# 300152     855            1               4      0             2
#
#         destination_city  class  duration  days_left  price
# 0                      5      1      2.17          1   5953
# 1                      5      1      2.33          1   5953
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
le = LinearRegression()

# %%
le.fit(x_train , y_train)
y_pred = le.predict(x_test)
y_pred
# Out:
# array([  212.69741753, 52340.43863005, 13671.24136044, ...,
#         7176.016622  , 10708.43477454,  8053.18856456])

# %%
result = pd.DataFrame(columns= ['Actual','Predicted'])
result['Actual']=y_test
result['Predicted']=y_pred
result
# Out:
#         Actual     Predicted
# 95478     5178    212.697418
# 286074   51595  52340.438630
# 61770     9879  13671.241360
# 32045     2098  -1306.622655
# 139635    8111   9059.228969
# ...        ...           ...
# 187791   11972   8582.613299
# 294399   60260  51474.331224
# 37404     6376   7176.016622
# 72996     3334  10708.434775
# 183505    4048   8053.188565
#
# [59925 rows x 2 columns]

# %%
from sklearn.metrics import *

# %%
res = r2_score(y_test , y_pred)
res
# Out:
# 0.9025314611595676

# %%
res*100
# Out:
# 90.25314611595677

# %%
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()

# %%
dt.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred1 = dt.predict(x_test)
y_pred1
# Out:
# array([ 5178., 51595., 12557., ...,  5333.,  3334.,  4048.])

# %%
result1 = pd.DataFrame(columns=['Actual','Predicted'])
result1['Actual'] = y_test
result1['Predicted'] = y_pred1
result1
# Out:
#         Actual  Predicted
# 95478     5178     5178.0
# 286074   51595    51595.0
# 61770     9879    12557.0
# 32045     2098     2098.0
# 139635    8111     8111.0
# ...        ...        ...
# 187791   11972     9715.0
# 294399   60260    60260.0
# 37404     6376     5333.0
# 72996     3334     3334.0
# 183505    4048     4048.0
#
# [59925 rows x 2 columns]

# %%
res1 = r2_score(y_test , y_pred1)
res1
# Out:
# 0.9832982508517308

# %%
res1*100
# Out:
# 98.32982508517308

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x_train , y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = rf.predict(x_test)
y_pred2
# Out:
# array([ 5202.72, 51595.  , 15210.3 , ...,  4626.12,  3334.  ,  4048.  ])

# %%
result2 = pd.DataFrame(columns=['Actual','Predicted'])
result2['Actual'] =y_test
result2['Predicted'] = y_pred2

# %%
result2
# Out:
#         Actual  Predicted
# 95478     5178    5202.72
# 286074   51595   51595.00
# 61770     9879   15210.30
# 32045     2098    2145.14
# 139635    8111    8111.00
# ...        ...        ...
# 187791   11972    8701.00
# 294399   60260   60260.00
# 37404     6376    4626.12
# 72996     3334    3334.00
# 183505    4048    4048.00
#
# [59925 rows x 2 columns]

# %%
res2 = r2_score(y_test , y_pred2)

# %%
res2
# Out:
# 0.9895439515180277

# %%
res2*100
# Out:
# 98.95439515180277

# %%
models ={
    'Linear Regression': LinearRegression(),
    'decision Tree':DecisionTreeRegressor(),
    'Random forest':RandomForestRegressor()
}

# %%
result ={}
for name, model in models.items():
  model.fit(x_train ,y_train)
  y_pred = model.predict(x_test)


  score = r2_score(y_test, y_pred)

  result[name] = score

# %%
for model, score in result.items():
  print(f" {model}: R2 SCORE{score: .4f}")
# Out:
#  Linear Regression: R2 SCORE 0.9025
#  decision Tree: R2 SCORE 0.9831
#  Random forest: R2 SCORE 0.9896

# %%
model_names = list(result.keys())
r2_scores = list(result.values())

plt.figure(figsize=(10, 6))
sns.barplot(x=model_names, y=r2_scores, palette='viridis')
plt.title('R2 Scores of Different Models')
plt.xlabel('Model')
plt.ylabel('R2 Score')
plt.ylim(0.8, 1.0)
# Out:
# /tmp/ipykernel_713/3136792235.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=model_names, y=r2_scores, palette='viridis')
# (0.8, 1.0)

# %%
# dimensionality reduction


# 1. feature selection  vif and rfe

# %%
df
# Out:
#         flight  source_city  departure_time  stops  arrival_time  \
# 0          786            2               2      2             5
# 1          765            2               1      2             4
# 2          591            2               1      2             1
# 3          937            2               4      2             0
# 4          927            2               4      2             4
# ...        ...          ...             ...    ...           ...
# 300148     855            1               4      0             2
# 300149     859            1               0      0             5
# 300150     864            1               1      0             5
# 300151     861            1               1      0             2
# 300152     855            1               4      0             2
#
#         destination_city  class  duration  days_left  price
# 0                      5      1      2.17          1   5953
# 1                      5      1      2.33          1   5953
# ...

# %%
def evaluate_score(name, y_test , y_pred):
  print(f"\n {name} Performance")
  print("R2  Score: ", r2_score(y_test, y_pred))
  print("MAE", mean_absolute_error(y_test , y_pred))
  print("MSE", mean_squared_error(y_test, y_pred))

# %%
evaluate_score("linear regression", y_test , y_pred)
evaluate_score("Decision Tree", y_test , y_pred1)
evaluate_score("Random Forest", y_test , y_pred2)
# Out:
#  linear regression Performance
# R2  Score:  0.9896262151124295
# MAE 880.5437851462476
# MSE 5362461.845804188
#
#  Decision Tree Performance
# R2  Score:  0.9832982508517308
# MAE 906.4182144347101
# MSE 8633540.557901544
#
#  Random Forest Performance
# R2  Score:  0.9895439515180277
# MAE 883.8120347836912
# MSE 5404985.899566626

# %%
from sklearn.model_selection import GridSearchCV

# %%
dt_params = {
     'max_depth': [3,5, 10, 15, None],
     'min_samples_split': [2, 5, 10],
     'min_samples_leaf':[1, 2, 4]

}

# %%
dt_grid = GridSearchCV(
    estimator = DecisionTreeRegressor(random_state  = 42),
    param_grid =dt_params,
    cv= 5,
    scoring ='r2'
)

# %%
dt_grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=42),
#              param_grid={'max_depth': [3, 5, 10, 15, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='r2')

# %%
best_dt = dt_grid.best_estimator_

# %%
best_dt
# Out:
# DecisionTreeRegressor(min_samples_leaf=4, min_samples_split=10, random_state=42)

# %%
y_pred1_dt_tuned = best_dt.predict(x_test)

# %%
y_pred1_dt_tuned
# Out:
# array([ 5703.        , 51595.        , 14036.        , ...,
#         5760.14285714,  3334.        ,  4048.        ])

# %%
evaluate_score('Tuned decision Tree', y_test, y_pred1_dt_tuned)
# Out:
#  Tuned decision Tree Performance
# R2  Score:  0.986954878749868
# MAE 984.609139380575
# MSE 6743340.616358766

# %% [markdown]
# ---
#
#
#
# #**Conclusion**
#
# This project successfully predicts flight ticket prices using multiple Machine Learning regression algorithms. The dataset was cleaned and preprocessed before training three different models: Linear Regression, Decision Tree Regressor, and Random Forest Regressor. The models were evaluated using R² Score, Mean Absolute Error (MAE), and Mean Squared Error (MSE).
#
# Among all the models, the Random Forest Regressor achieved the best performance with an R² Score of approximately 98.96%, making it the most accurate model for predicting flight prices. Hyperparameter tuning using GridSearchCV was also performed on the Decision Tree model to improve its performance.
#
# This project demonstrates how machine learning techniques can help airlines and customers estimate ticket prices accurately based on historical flight data.
#
#
# ---
#
# #**Key Findings**
#
# - Dataset was successfully cleaned and preprocessed.
#
# - Three regression algorithms were implemented.
#
# - Performance was evaluated using R² Score, MAE, and MSE.
#
# - Random Forest Regressor achieved the highest prediction accuracy.
#
# - GridSearchCV improved the Decision Tree model through hyperparameter tuning.
#
# - Model comparison was visualized using a bar chart.
#
# - The project can be extended for real-time flight fare prediction.
#
#
#
# ---
#
# #**Technologies Used**
#
# - Python
#
# - NumPy
#
# - Pandas
#
# - Matplotlib
#
# - Seaborn
#
# - Scikit-learn
#
# - Google Colab
#
#
#
# ---
#
# #**Machine Learning Models Used**
#
# - Linear Regression
#
# - Decision Tree Regressor
#
# - Random Forest Regressor
#
#
#
# ---
#
# #**Evaluation Metrics**
#
# - R² Score
#
# - Mean Absolute Error (MAE)
#
# - Mean Squared Error (MSE)
#
#
#
# ---
#
# #**Future Scope**
#
# - Deploy the model using Flask or Streamlit.
#
# - Create a user-friendly web application for fare prediction.
#
# - Train the model on real-time flight booking data.
#
# - Include additional features such as airline ratings, weather conditions, holiday seasons, and demand trends.
#
# - Improve accuracy using advanced models like XGBoost, LightGBM, or CatBoost.
#
# - Integrate the model with online travel booking platforms.
#
#
#
# ---
#
#
#
# #**Learning Outcomes**
#
# - Through this project, I learned:
#
# - Data preprocessing and feature engineering
#
# - Training regression models
#
# - Model evaluation techniques
#
# - Hyperparameter tuning using GridSearchCV
#
# - Performance comparison of different algorithms
#
# - Data visualization
#
# - Building an end-to-end Machine Learning pipeline
#
#
#
# ---
#
# #**Final Result**
#
# Model : R² Score
#
# Linear Regression : 0.9025 (90.25%)
#
# Decision Tree Regressor :  0.9832 (98.32%)
#
# Random Forest Regressor : 0.9896 (98.96%) ⭐ Best Model
# Tuned Decision Tree : 0.9870 (98.70%)
#
#
#
#
#
# ---
#
# #**Acknowledgement**
#
# This project was developed as part of my Machine Learning learning journey to understand regression algorithms, model evaluation, and hyperparameter tuning. It demonstrates the practical application of supervised learning techniques for predicting flight ticket prices and highlights the importance of selecting the most effective model based on performance metrics.
